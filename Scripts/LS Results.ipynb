# %%
import sys
from optparse import OptionParser
import math


class TSAR2022_SharedTask_Evaluator(object):

    def __init__(self,output_file,verbose):
        self.verbose=verbose
        self.output_file=output_file
        self.combined = None
        self.goldinfo = None
        self.flagUseComplexWordsInGoldAnnotations=False
        

        
    def match(self,label, gold_annotation):

        if label == gold_annotation:
            return True
        return False

        
    
        
    def match_group(self,label, gold_annotations):
        
        for g in gold_annotations:
            if self.match(label, g):
                return True
        return False


    def match_group_to_group(self,list_labels, gold_annotations):
        
        for label in list_labels:
            if self.match_group(label, gold_annotations):
                return True
        return False
    
    

    def read_files(self,gold_file, labels_file):

        self.gold_file=gold_file
        self.labels_file=labels_file
        
        if self.verbose:
            print("______________________________________________________")
            print("gold_file:",gold_file)
            print("labels_file:",labels_file)
            print("______________________________________________________")
        
        # Read files
        gold_lines = open(gold_file,'r').readlines()
        labels_lines = open(labels_file,'r').readlines()
        
        
        self.goldinfo={}
        
        if self.verbose:
            print("______________________________________________________")
            print("_____________ GOLD ANNOTATIONS FILE __________________")
            print("______________________________________________________")
        
        
        for line in gold_lines:
            split = line.strip().split("\t")
            keygold = split[0].replace("\"","").strip() + "__" + split[1].replace("\"","").strip() # ADDED - MS 28/3/24

            
            complex_word=split[1]
            
            if self.verbose:
                print("keygold:", keygold)
            
            
            items = [item.strip() for item in split[2:]]
            
            if self.verbose:
                print("items:", items)
            
            dict_items={}
            
            for item in items:
                
                if self.flagUseComplexWordsInGoldAnnotations==False:
                
                
                    if item!=complex_word:
                        if item in dict_items.keys():
                            dict_items[item]+=1
                        else:
                            dict_items[item]=1
                        
                else:
                    
                    if item in dict_items.keys():
                        dict_items[item]+=1
                    else:
                        dict_items[item]=1
                        
                        
            if self.verbose:
                print("goldinfo ITEMS:", dict_items)
                    
            
            dict_values_items={}
            
            for value in dict_items.values():
                dict_values_items[value]=[]
            
            for k in dict_items.keys():
                if k not in dict_values_items[dict_items[k]]:
                    dict_values_items[dict_items[k]].append(k)
            
            list_num_counts_items=sorted(dict_values_items.keys())
            list_num_counts_items.reverse()
                        
            if self.verbose:
                print("list_num_counts_items:", list_num_counts_items)
            
            list_values_items_lists=[]
            for key in list_num_counts_items:
                list_values_items_lists.append(dict_values_items[key])
    
            
            if self.verbose:
                print("list_values_items_lists:", list_values_items_lists)
            
            
            self.goldinfo[keygold] = {'gold': dict_items.keys(), 'list_values': list_num_counts_items,'list_keys_lists':list_values_items_lists}

            
            if self.verbose:
                print("goldinfo:", self.goldinfo[keygold])
                print("______________________________________________________")
            
        
        
        
        
        
        self.combined={}

        
        if self.verbose:
            print("______________________________________________________")
            print("_____________ PREDICTIONS FILE _______________________")
            print("______________________________________________________")
        
        i = 0

        for line in labels_lines:
            split = line.strip().split("\t")
            try:  # MS - DEBUG
                i += 1
                key = split[0] + "__" + split[1]
            except Exception as exception:
                print(line)
                raise exception
            key = split[0].replace("\"","").strip() + "__" + split[1].replace("\"","").strip() # ADDED - MS 28/3/24
            items = [item.strip() for item in split[2:]]
            
            
            
            if self.verbose:
                print("______________________________________________________")
                print("original_items:", items)
            
            
            #filtering out complex words in the predicted labels and repeated predictions
            complex_word=split[1]
            filtered_items=[]
            
            for item in items:
                if item not in filtered_items and not item==complex_word:
                    filtered_items.append(item) 
            
            
            if self.verbose:
                print("filtered_items:", filtered_items)
                print("______________________________________________________")
            
            
            
            self.combined[key] = { 'labels': filtered_items }

        
    
        
        
        
    def computeAccuracy_at_1(self):
        
        # Accuracy Metric

        if self.verbose:
            print()
            print()
            print("############################")
            print("    Accuracy Metric ACC@1")
            print("############################")
            print()
            print("______________________________________________________")

        tp = 0
        total = 0

        for key in self.combined.keys():
            
            
            if self.combined[key]['labels']!=None and len(self.combined[key]['labels'])>0:
                if self.verbose:
                    print("______________________________________________________")
                    print("Context = " + str(self.combined[key]))
                    print("Gold  = ",self.goldinfo[key]['gold'])
                    print("Label = ",self.combined[key]['labels'])
                    print("Label topk=1 =",self.combined[key]['labels'][0])
    
                    
                sentence,complexWord=key.split('__')
                if self.match_group(self.combined[key]['labels'][0],self.goldinfo[key]['gold']):
                    if self.verbose:
                        print("MATCH @acc1_set_gold=",self.combined[key]['labels'][0])
                        print("______________________________________________________")
                    tp += 1
                elif self.verbose:
                        print("NO MATCH\n")
                        print("______________________________________________________")
                        

            total += 1

            
        if self.verbose:
            print("TOTALMATCHES acc@1: ",str(tp))
            print("______________________________________________________")
            
        accuracy = tp/total
                   
        return accuracy


    def computeAccuracy_at_N_at_top_gold_1(self,N):
        
        # Accuracy Metric

        if self.verbose:
            print()
            print()
            print("#############################################")
            print("    Accuracy Metric @",N,"@ GOLD FIRST MATCH")
            print("#############################################")
            print()
            print("______________________________________________________")

        tp = 0
        total = 0

        for key in self.combined.keys():

            if self.combined[key]['labels']!=None and len(self.combined[key]['labels'])>0:

            
                if self.verbose:
                    print("______________________________________________________")
                    print("Context = " + str(self.combined[key]))
                    print("Gold  = ",self.goldinfo[key]['gold'])
                    print("Label = ",self.combined[key]['labels'])
                    print("Label topN=",N," ",self.combined[key]['labels'][0:N])
                    print("Gold topk=1 list =", self.goldinfo[key]['list_keys_lists'][0])
                    
    
                sentence,complexWord=key.split('__')
                if self.match_group_to_group(self.combined[key]['labels'][0:N],self.goldinfo[key]['list_keys_lists'][0]):
                    if self.verbose:
                        print("MATCH acc@N_gold_first=",self.combined[key]['labels'][0:N])
                        print("______________________________________________________")
                    tp += 1
                elif self.verbose:
                        print("NO MATCH\n")
                        print("______________________________________________________")
                        

            total += 1

        
        
        if self.verbose:    
            print("TOTALMATCHES accuracy@",N,"_at_top_gold_1:",str(tp))
            print("______________________________________________________")
            
        accuracy = tp/total
                   
        return accuracy

  
   
    
    
    def computePrecisionMetrics_at_K(self,K):
                   
        # Precision

        if self.verbose:
            print()
            print()
            print("##############################################################################################")
            print("     Potential, MicroAverage and MacroAverage Precision, Recall and F1 Metrics at ",K)
            print("##############################################################################################")
            print()


        MacroAverage_Precision = 0
        MicroAverage_Precision = 0
        MacroAverage_Recall = 0
        MicroAverage_Recall = 0
        MacroAverage_F1 = 0
        MicroAverage_F1 = 0

        running_precision = 0
        total_counts_precision=0
        running_recall = 0
        total_counts_recall=0
        total_counts_labels=0

        potential_counts=0
        Potential=0

        total = 0

        for key in self.combined.keys():
            
            
            if self.combined[key]['labels']!=None and len(self.combined[key]['labels'])>0:

                if self.verbose:
                    print("______________________________________________________")
                    print("Context = " + str(self.combined[key]))
                    print("Gold  = " + str(self.goldinfo[key]['gold']))
                    print("Label = " + str(self.combined[key]['labels']))
    
                gold_annotations= self.goldinfo[key]['gold']
                
                labels = self.combined[key]['labels'][0:K]
    
                total_counts_labels+=len(labels)
    
                sentence,complexWord=key.split('__')
                acc_labels = [l for l in labels if self.match_group( l, gold_annotations)]
                acc_gold = [l for l in gold_annotations if self.match_group(l, labels)]
    
    
                total_counts_precision+=len(acc_labels)
    
                if len(acc_labels)>0:
                    potential_counts+=1
    
                total_counts_recall+=len(acc_gold)
    
                precision = len(acc_labels) / len(labels)
                recall = len(acc_gold) / len(gold_annotations)
    
    
                if self.verbose:
                    print("Matched Labels with respect Gold = " +str(acc_labels))
                    print("Matched Gold with respect Labels = " +str(acc_gold))
                    print("Precision = " + str(precision))
                    print("Recall = " + str(recall)+"\n")
                    print("______________________________________________________")
                    
    
                running_precision += precision
                running_recall += recall

            total += 1

        MacroAverage_Precision = running_precision / total
        MacroAverage_Recall = running_recall / total


        if total_counts_labels>0:
            
            MicroAverage_Precision= total_counts_precision / total_counts_labels
            MicroAverage_Recall = total_counts_recall / total_counts_labels
            
            

        MacroAverage_F1=0
        MicroAverage_F1=0


        if (MacroAverage_Precision+MacroAverage_Recall)>0:
                    MacroAverage_F1 = 2*MacroAverage_Precision*MacroAverage_Recall/(MacroAverage_Precision+MacroAverage_Recall)
                    MicroAverage_F1 = 2*MicroAverage_Precision*MicroAverage_Recall/(MicroAverage_Precision+MicroAverage_Recall)

        if (potential_counts>0):
            Potential=potential_counts/total

                   
                   
                   
        return MacroAverage_Precision,MacroAverage_Recall,MacroAverage_F1,MicroAverage_Precision,MicroAverage_Recall,MicroAverage_F1, Potential


               
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
                   
    #Mean Average Precision
    # Parameters : 
    #  1. List of Binary Relevance Judgments e.g. [False, True, True, False, False]
    #  2. K
    

    def MAP_at_K(self,list_gold_items_match,K):
        MAP = 0
        AP = 0

        TruePositivesSeen=0
        index=0

        
        list_precision_calculations=[]
        for item in list_gold_items_match:
            index+=1
            if index>K:
                break
            if item==True:
                TruePositivesSeen+=1
                precision=TruePositivesSeen/index
                list_precision_calculations.append(precision)
                AP+=precision
            
            else:
                list_precision_calculations.append(0)
            

        MAP=AP/K

        
        if self.verbose:
            print("list_precision_calculations:", list_precision_calculations)
            print("AP:", AP)
            print("K:", K)
            print("MAP:", MAP)
            print("______________________________________________________")
        
        
        return MAP

                   
                   
                   
    def computeMAP_at_K(self,K):

        # MAP metric

        if self.verbose:
            print()
            print()
            print("###########################################################################")
            print("         MeanAveragePrecision (MAP) metric @",K)
            print("###########################################################################")
            print()
    
        total_instances=0   
        MAP_global_accumulator=0
        MAP=0          

        
    
        for key in self.combined.keys():
            if self.verbose:
                print("______________________________________________________")
                print("Context = " + str(self.combined[key]))
                print("Gold  = " + str(self.goldinfo[key]['gold']))
                print("Label = " + str(self.combined[key]['labels']))

            gold = set(self.goldinfo[key]['gold'])
            labels = set(self.combined[key]['labels'])

            list_labels=self.combined[key]['labels']
            gold_annotations=self.goldinfo[key]['gold']


            #########################################
            # MAP 
            #########################################

            
            if self.verbose:
                print("MAP")
                print("labels:",list_labels)
                print("gold:", gold_annotations)

            
            sentence,complexWord=key.split('__')

            labels_relevance_judgements=[]
            for label in list_labels:
                labels_relevance_judgements.append(self.match_group(label, gold_annotations))

            if self.verbose:
                print("labels_relevance_judgements:")
                print(labels_relevance_judgements)

            MAP_local=self.MAP_at_K(labels_relevance_judgements,K)
            MAP_global_accumulator+=MAP_local
            total_instances+=1 
                   
                   
                   
        if (MAP_global_accumulator>0):
    
            MAP=MAP_global_accumulator/total_instances
           
        return MAP       



                   
    def print_output_results(self, Potential_at_1,
                                   Potential_at_3,
                                   Potential_at_5,
                                   Potential_at_10,
                                   MAP_at_3,
                                   MAP_at_5,
                                   MAP_at_10,
                                   Accuracy_at_1_at_top_gold_1,
                                   Accuracy_at_2_at_top_gold_1,
                                   Accuracy_at_3_at_top_gold_1):
        
    

        
        print("=========   EVALUATION config.=========")
                   
        print('GOLD file = ' + str(self.gold_file))
        print('PREDICTION LABELS file = ' + str(self.labels_file))
        print('OUTPUT file = ' + str(self.output_file))
        print("===============   RESULTS  =============\n")
    
    
    
        print('MAP@1/Potential@1/Precision@1 = ' + str(Potential_at_1)+"\n")
    
        print('MAP@3 = ' + str(MAP_at_3))
        print('MAP@5 = ' + str(MAP_at_5))
        print('MAP@10 = ' + str(MAP_at_10)+"\n")

        print('Potential@3 = ' + str(Potential_at_3))
        print('Potential@5 = ' + str(Potential_at_5))
        print('Potential@10 = ' + str(Potential_at_10)+"\n")
        
        
        print('Accuracy@1@top_gold_1 = ' + str(Accuracy_at_1_at_top_gold_1))
        print('Accuracy@2@top_gold_1 = ' + str(Accuracy_at_2_at_top_gold_1))
        print('Accuracy@3@top_gold_1 = ' + str(Accuracy_at_3_at_top_gold_1))
        print('\n')
    
    
    
    
    def write_output_results(self, Potential_at_1,
                                   Potential_at_3,
                                   Potential_at_5,
                                   Potential_at_10,
                                   MAP_at_3,
                                   MAP_at_5,
                                   MAP_at_10,
                                   Accuracy_at_1_at_top_gold_1,
                                   Accuracy_at_2_at_top_gold_1,
                                   Accuracy_at_3_at_top_gold_1):
        
    
    
    
        out_file = open(self.output_file,mode='w',encoding='utf-8')
    
    
        out_file.write("=========   EVALUATION config.=========\n")
                       
        out_file.write('GOLD file = ' + str(self.gold_file)+'\n')
        out_file.write('PREDICTION LABELS file = ' + str(self.labels_file)+'\n')
        out_file.write('OUTPUT file = ' + str(self.output_file)+'\n')
        out_file.write("===============   RESULTS  =============\n")
        
        
        out_file.write('MAP@1/Potential@1/Precision@1 = ' + str(Potential_at_1)+'\n\n')
        
    
        out_file.write('MAP@3 = ' + str(MAP_at_3)+'\n')
        out_file.write('MAP@5 = ' + str(MAP_at_5)+'\n')
        out_file.write('MAP@10 = ' + str(MAP_at_10)+'\n\n')
  
        
        out_file.write('Potential@3 = ' + str(Potential_at_3)+'\n')
        out_file.write('Potential@5 = ' + str(Potential_at_5)+'\n')
        out_file.write('Potential@10 = ' + str(Potential_at_10)+'\n\n')
        
        out_file.write('Accuracy@1@top_gold_1 = ' + str(Accuracy_at_1_at_top_gold_1)+'\n')
        out_file.write('Accuracy@2@top_gold_1 = ' + str(Accuracy_at_2_at_top_gold_1)+'\n')
        out_file.write('Accuracy@3@top_gold_1 = ' + str(Accuracy_at_3_at_top_gold_1)+'\n\n')
        
        out_file.write('________________________________\n')
        out_file.close()
    
    
    
  

def main():

    
    # arg parsing
    parser = OptionParser(usage='Evaluation Script for the TSAR-2022 Lexical Simplification Shared Task\n\nUsage: %prog <options>')

    parser.add_option('--gold_file', metavar='<PATH>', action='store', type='string', dest='gold_file', default='', help='The path to the file with the gold annotated instances')
    parser.add_option('--predictions_file', metavar='<PATH>',  action='store', type='string', dest='predictions_file', default='', help='The path to file with the predictions')
    parser.add_option('--output_file', metavar='<PATH>', action='store', type='string',dest='output_file', default='', help='path to the output file')
    parser.add_option('--verbose', help='Verbose output mode',  action='store_true')
    
    

    
    (options, args) = parser.parse_args(sys.argv) 
    
    if (options.gold_file==''):
        print("Error: input path to the file with gold annotations is missing!")
        print(parser.print_help())
        sys.exit(1)


    if (options.predictions_file==''):
        print("Error: input path to the predictions file is missing!")
        print(parser.print_help())
        sys.exit(1)


    if (options.output_file==''):
        print("Error: path to the output file is missing!")
        print(parser.print_help())
        sys.exit(1)


    
    evaluator=TSAR2022_SharedTask_Evaluator(options.output_file,options.verbose)
    evaluator.read_files(options.gold_file,options.predictions_file)

    
    Accuracy_at_1_at_top_gold_1=evaluator.computeAccuracy_at_N_at_top_gold_1(1)
    Accuracy_at_2_at_top_gold_1=evaluator.computeAccuracy_at_N_at_top_gold_1(2)
    Accuracy_at_3_at_top_gold_1=evaluator.computeAccuracy_at_N_at_top_gold_1(3)
    
    
    MacroAverage_Precision_at_1, MacroAverage_Recall_at_1, MacroAverage_F1_at_1, MicroAverage_Precision_at_1, MicroAverage_Recall_at_1, MicroAverage_F1_at_1, Potential_at_1=evaluator.computePrecisionMetrics_at_K(1)
    MacroAverage_Precision_at_3, MacroAverage_Recall_at_3, MacroAverage_F1_at_3, MicroAverage_Precision_at_3, MicroAverage_Recall_at_3, MicroAverage_F1_at_3, Potential_at_3=evaluator.computePrecisionMetrics_at_K(3)
    MacroAverage_Precision_at_5, MacroAverage_Recall_at_5, MacroAverage_F1_at_5, MicroAverage_Precision_at_5, MicroAverage_Recall_at_5, MicroAverage_F1_at_5, Potential_at_5=evaluator.computePrecisionMetrics_at_K(5)
    MacroAverage_Precision_at_10, MacroAverage_Recall_at_10, MacroAverage_F1_at_10, MicroAverage_Precision_at_10, MicroAverage_Recall_at_10, MicroAverage_F1_at_10, Potential_at_10=evaluator.computePrecisionMetrics_at_K(10)

    MAP_at_3=evaluator.computeMAP_at_K(3)
    MAP_at_5=evaluator.computeMAP_at_K(5)
    MAP_at_10=evaluator.computeMAP_at_K(10)
        
    
    
    factor=10000  #floor 4 decimal numbers
    
    Accuracy_at_1_at_top_gold_1_floored=math.floor(Accuracy_at_1_at_top_gold_1 * factor) / factor
    Accuracy_at_2_at_top_gold_1_floored=math.floor(Accuracy_at_2_at_top_gold_1 * factor) / factor
    Accuracy_at_3_at_top_gold_1_floored=math.floor(Accuracy_at_3_at_top_gold_1 * factor) / factor
    
    Potential_at_1_floored=math.floor(Potential_at_1 * factor) / factor
    Potential_at_3_floored=math.floor(Potential_at_3 * factor) / factor
    Potential_at_5_floored=math.floor(Potential_at_5 * factor) / factor
    Potential_at_10_floored=math.floor(Potential_at_10 * factor) / factor
    
    MAP_at_3_floored=math.floor(MAP_at_3 * factor) / factor
    MAP_at_5_floored=math.floor(MAP_at_5 * factor) / factor
    MAP_at_10_floored=math.floor(MAP_at_10 * factor) / factor
    
    
    
    evaluator.print_output_results(Potential_at_1_floored,
                                   Potential_at_3_floored,
                                   Potential_at_5_floored,
                                   Potential_at_10_floored,
                                   MAP_at_3_floored,
                                   MAP_at_5_floored,
                                   MAP_at_10_floored,
                                   Accuracy_at_1_at_top_gold_1_floored,
                                   Accuracy_at_2_at_top_gold_1_floored,
                                   Accuracy_at_3_at_top_gold_1_floored)
    
    
    
    evaluator.write_output_results(Potential_at_1_floored,
                                   Potential_at_3_floored,
                                   Potential_at_5_floored,
                                   Potential_at_10_floored,
                                   MAP_at_3_floored,
                                   MAP_at_5_floored,
                                   MAP_at_10_floored,
                                   Accuracy_at_1_at_top_gold_1_floored,
                                   Accuracy_at_2_at_top_gold_1_floored,
                                   Accuracy_at_3_at_top_gold_1_floored)




    
    
# if __name__ == '__main__':
#     main()

# %%
def call_ls_evaluate(gold_file,predictions_file,verbose,lang):
    evaluator=TSAR2022_SharedTask_Evaluator("",verbose)
    evaluator.flagUseComplexWordsInGoldAnnotations = True
    evaluator.read_files(gold_file,predictions_file)

    
    Accuracy_at_1_at_top_gold_1=evaluator.computeAccuracy_at_N_at_top_gold_1(1)
    Accuracy_at_2_at_top_gold_1=evaluator.computeAccuracy_at_N_at_top_gold_1(2)
    Accuracy_at_3_at_top_gold_1=evaluator.computeAccuracy_at_N_at_top_gold_1(3)
    
    
    MacroAverage_Precision_at_1, MacroAverage_Recall_at_1, MacroAverage_F1_at_1, MicroAverage_Precision_at_1, MicroAverage_Recall_at_1, MicroAverage_F1_at_1, Potential_at_1=evaluator.computePrecisionMetrics_at_K(1)
    MacroAverage_Precision_at_3, MacroAverage_Recall_at_3, MacroAverage_F1_at_3, MicroAverage_Precision_at_3, MicroAverage_Recall_at_3, MicroAverage_F1_at_3, Potential_at_3=evaluator.computePrecisionMetrics_at_K(3)
    MacroAverage_Precision_at_5, MacroAverage_Recall_at_5, MacroAverage_F1_at_5, MicroAverage_Precision_at_5, MicroAverage_Recall_at_5, MicroAverage_F1_at_5, Potential_at_5=evaluator.computePrecisionMetrics_at_K(5)
    MacroAverage_Precision_at_10, MacroAverage_Recall_at_10, MacroAverage_F1_at_10, MicroAverage_Precision_at_10, MicroAverage_Recall_at_10, MicroAverage_F1_at_10, Potential_at_10=evaluator.computePrecisionMetrics_at_K(10)

    MAP_at_3=evaluator.computeMAP_at_K(3)
    MAP_at_5=evaluator.computeMAP_at_K(5)
    MAP_at_10=evaluator.computeMAP_at_K(10)
        
    
    
    factor=10000  #floor 4 decimal numbers
    
    Accuracy_at_1_at_top_gold_1_floored=math.floor(Accuracy_at_1_at_top_gold_1 * factor) / factor
    Accuracy_at_2_at_top_gold_1_floored=math.floor(Accuracy_at_2_at_top_gold_1 * factor) / factor
    Accuracy_at_3_at_top_gold_1_floored=math.floor(Accuracy_at_3_at_top_gold_1 * factor) / factor
    
    Potential_at_1_floored=math.floor(Potential_at_1 * factor) / factor
    Potential_at_3_floored=math.floor(Potential_at_3 * factor) / factor
    Potential_at_5_floored=math.floor(Potential_at_5 * factor) / factor
    Potential_at_10_floored=math.floor(Potential_at_10 * factor) / factor
    
    MAP_at_3_floored=math.floor(MAP_at_3 * factor) / factor
    MAP_at_5_floored=math.floor(MAP_at_5 * factor) / factor
    MAP_at_10_floored=math.floor(MAP_at_10 * factor) / factor
    
    results = (Accuracy_at_1_at_top_gold_1_floored, Accuracy_at_2_at_top_gold_1_floored, Accuracy_at_3_at_top_gold_1_floored, Potential_at_1_floored, Potential_at_3_floored, Potential_at_5_floored, Potential_at_10_floored, MAP_at_3_floored, MAP_at_5_floored, MAP_at_10_floored)
    
    parts = predictions_file.split("/")
    print("%s\t%s\t%s\t%s\t%f\t%f\t%f\t%f\t%f\t%f\t%f\t%f\t%f\t%f" % ((predictions_file, parts[1], lang, parts[2][-5]) + results))

# %%
import glob

# %%
#per lang results

lang_ids = ["ca","en","fil","fr","de","it","ja","pt","si","es"]

lang_dict = {"ca":"Catalan", 
             "en":"English",
             "fil":"Filipino",
             "fr":"French",
             "de":"German",
             "it":"Italian",
             "ja":"Japanese",
             "pt":"Portuguese",
             "si":"Sinhala",
             "es":"Spanish"}

stop_on_error = False

for lang_id in lang_ids:
    lang = lang_dict[lang_id]
    gold = "MLSP_Organisers/Gold/" + lang + "/multilex_test_" + lang.lower() + "_ls_labels.tsv"
    sys_files = glob.glob("MLSP_Participants/*/multilex_test_" + lang_id + "_ls*")
    for output_file in sys_files:
        try:
            call_ls_evaluate(gold,output_file,False,lang)
        except Exception as exception:
            if stop_on_error:
                print(gold)
                print(output_file)
                raise exception
            else:
                print(output_file +"\t could not parse")
# Out:
# MLSP_Participants/Archaeology/multilex_test_ca_ls_1.tsv	Archaeology	Catalan	1	0.029200	0.047100	0.065100	0.101100	0.251600	0.357300	0.521300	0.069000	0.055600	0.038600
# MLSP_Participants/Archaeology/multilex_test_ca_ls_2.tsv	Archaeology	Catalan	2	0.040400	0.080800	0.110100	0.186500	0.361700	0.476400	0.613400	0.120300	0.097200	0.062300
# MLSP_Participants/Baseline/multilex_test_ca_ls.tsv	Baseline	Catalan	s	0.197700	0.267400	0.289800	0.496600	0.642600	0.687600	0.712300	0.300000	0.212100	0.120200
# MLSP_Participants/GMU/multilex_test_ca_ls_A2.tsv	GMU	Catalan	2	0.058400	0.089800	0.134800	0.193200	0.420200	0.550500	0.678600	0.132000	0.103400	0.067200
# MLSP_Participants/GMU/multilex_test_ca_ls_A1.tsv	GMU	Catalan	1	0.224700	0.305600	0.328000	0.534800	0.707800	0.755000	0.802200	0.361200	0.263600	0.157900
# MLSP_Participants/GMU/multilex_test_ca_ls_1.tsv	GMU	Catalan	1	0.224700	0.305600	0.328000	0.537000	0.710100	0.757300	0.804400	0.362000	0.264100	0.158200
# MLSP_Participants/GMU/multilex_test_ca_ls_2.tsv	GMU	Catalan	2	0.065100	0.119100	0.159500	0.242600	0.519100	0.640400	0.755000	0.172000	0.140800	0.089300
# MLSP_Participants/dummy2/multilex_test_ca_ls_1.tsv	dummy2	Catalan	1	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000
# MLSP_Participants/dummy2/multilex_test_ca_ls_2.tsv	dummy2	Catalan	2	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000
# MLSP_Participants/TMU-HIT/multilex_test_ca_ls_A2.tsv	TMU-HIT	Catalan	2	0.251600	0.334800	0.370700	0.606700	0.813400	0.858400	0.907800	0.457800	0.348000	0.210400
# MLSP_Participants/TMU-HIT/multilex_test_ca_ls_A3.tsv	TMU-HIT	Catalan	3	0.195500	0.294300	0.370700	0.600000	0.813400	0.858400	0.907800	0.452800	0.345000	0.208900
# MLSP_Participants/TMU-HIT/multilex_test_ca_ls_A1.tsv	TMU-HIT	Catalan	1	0.258400	0.337000	0.370700	0.660600	0.813400	0.858400	0.907800	0.469000	0.354700	0.213800
# MLSP_Participants/RETUYT-INCO/multilex_test_ca_ls_A2.tsv	RETUYT-INCO	Catalan	2	0.193200	0.258400	0.283100	0.498800	0.653900	0.694300	0.755000	0.307700	0.210600	0.115700
# MLSP_Participants/RETUYT-INCO/multilex_test_ca_ls_A1.tsv	RETUYT-INCO	Catalan	1	0.197700	0.262900	0.294300	0.489800	0.656100	0.705600	0.739300	0.302400	0.210000	0.114400
# MLSP_Participants/ISEP_Presidency_University/multilex_test_ca_ls_1.tsv	ISEP_Presidency_University	Catalan	1	0.271900	0.348300	0.393200	0.678600	0.851600	0.901100	0.928000	0.500300	0.375900	0.223800
# MLSP_Participants/ANU/multilex_test_en_ls_1.tsv	ANU	English	1	0.468400	0.592900	0.656100	0.735000	0.868400	0.901700	0.922800	0.506900	0.365200	0.203500
# MLSP_Participants/ANU/multilex_test_en_ls_2.tsv	ANU	English	2	0.463100	0.580700	0.642100	0.722800	0.861400	0.882400	0.894700	0.497800	0.352400	0.193900
# MLSP_Participants/ANU/multilex_test_en_ls_3.tsv	ANU	English	3	0.510500	0.617500	0.664900	0.768400	0.882400	0.898200	0.905200	0.532400	0.374400	0.204100
# MLSP_Participants/Archaeology/multilex_test_en_ls_2.tsv	Archaeology	English	2	0.094700	0.187700	0.257800	0.210500	0.452600	0.571900	0.743800	0.151000	0.127200	0.087500
# MLSP_Participants/Baseline/multilex_test_en_ls.tsv	Baseline	English	s	0.387700	0.508700	0.563100	0.633300	0.777100	0.812200	0.831500	0.424100	0.295600	0.162400
# MLSP_Participants/GMU/multilex_test_en_ls_1.tsv	GMU	English	1	0.515700	0.635000	0.689400	0.749100	0.875400	0.907000	0.928000	0.513000	0.369100	0.209500
# MLSP_Participants/GMU/multilex_test_en_ls_2.tsv	GMU	English	2	0.185900	0.284200	0.356100	0.298200	0.573600	0.721000	0.777100	0.194500	0.145400	0.077400
# MLSP_Participants/GMU/multilex_test_en_ls_A2.tsv	GMU	English	2	0.192900	0.322800	0.415700	0.335000	0.631500	0.764900	0.864900	0.233900	0.186900	0.110600
# MLSP_Participants/GMU/multilex_test_en_ls_A1.tsv	GMU	English	1	0.515700	0.635000	0.689400	0.749100	0.875400	0.907000	0.928000	0.513000	0.369100	0.209500
# MLSP_Participants/CocoNut/multilex_test_en_ls_1.tsv	CocoNut	English	1	0.229800	0.333300	0.387700	0.363100	0.582400	0.689400	0.773600	0.230300	0.167400	0.099100
# MLSP_Participants/dummy2/multilex_test_en_ls_1.tsv	dummy2	English	1	0.000000	0.000000	0.000000	0.000000	0.001700	0.001700	0.005200	0.000100	0.000100	0.000100
# MLSP_Participants/TMU-HIT/multilex_test_en_ls_1.tsv	TMU-HIT	English	1	0.524500	0.680700	0.745600	0.798200	0.903500	0.935000	0.961400	0.576200	0.414200	0.232400
# MLSP_Participants/TMU-HIT/multilex_test_en_ls_2.tsv	TMU-HIT	English	2	0.443800	0.629800	0.745600	0.733300	0.903500	0.935000	0.961400	0.559500	0.404200	0.227400
# MLSP_Participants/TMU-HIT/multilex_test_en_ls_3.tsv	TMU-HIT	English	3	0.438500	0.657800	0.745600	0.728000	0.903500	0.935000	0.961400	0.560400	0.404800	0.227700
# MLSP_Participants/TMU-HIT/multilex_test_en_ls_A2.tsv	TMU-HIT	English	2	0.443800	0.629800	0.745600	0.733300	0.903500	0.935000	0.961400	0.559500	0.404200	0.227400
# MLSP_Participants/TMU-HIT/multilex_test_en_ls_A3.tsv	TMU-HIT	English	3	0.438500	0.657800	0.745600	0.728000	0.903500	0.935000	0.961400	0.560400	0.404800	0.227700
# MLSP_Participants/TMU-HIT/multilex_test_en_ls_A1.tsv	TMU-HIT	English	1	0.524500	0.680700	0.745600	0.798200	0.903500	0.935000	0.961400	0.576200	0.414200	0.232400
# MLSP_Participants/RETUYT-INCO/multilex_test_en_ls_1.tsv	RETUYT-INCO	English	1	0.082400	0.126300	0.156100	0.159600	0.277100	0.343800	0.464900	0.092000	0.062900	0.037900
# MLSP_Participants/RETUYT-INCO/multilex_test_en_ls_2.tsv	RETUYT-INCO	English	2	0.343800	0.470100	0.552600	0.578900	0.766600	0.808700	0.857800	0.371800	0.254200	0.135500
# MLSP_Participants/RETUYT-INCO/multilex_test_en_ls_3.tsv	RETUYT-INCO	English	3	0.378900	0.510500	0.570100	0.594700	0.782400	0.828000	0.854300	0.383200	0.263400	0.139400
# MLSP_Participants/RETUYT-INCO/multilex_test_en_ls_A2.tsv	RETUYT-INCO	English	2	0.378900	0.510500	0.570100	0.594700	0.782400	0.828000	0.854300	0.383200	0.263400	0.139400
# MLSP_Participants/RETUYT-INCO/multilex_test_en_ls_A1.tsv	RETUYT-INCO	English	1	0.343800	0.470100	0.552600	0.578900	0.766600	0.808700	0.857800	0.371800	0.254200	0.135500
# MLSP_Participants/SCaLAR/multilex_test_en_ls_1.tsv	 could not parse
# MLSP_Participants/ISEP_Presidency_University/multilex_test_en_ls_1.tsv	ISEP_Presidency_University	English	1	0.468400	0.607000	0.675400	0.764900	0.885900	0.933300	0.959600	0.535100	0.387700	0.217900
# MLSP_Participants/Archaeology/multilex_test_fil_ls_2.tsv	Archaeology	Filipino	2	0.007000	0.010500	0.012200	0.024500	0.057800	0.073600	0.092900	0.014100	0.009500	0.005100
# MLSP_Participants/Archaeology/multilex_test_fil_ls_1.tsv	Archaeology	Filipino	1	0.017500	0.028000	0.029800	0.052600	0.131500	0.170100	0.228000	0.031300	0.021500	0.011800
# MLSP_Participants/Baseline/multilex_test_fil_ls.tsv	Baseline	Filipino	s	0.007000	0.007000	0.007000	0.050800	0.071900	0.078900	0.078900	0.022500	0.014000	0.007000
# MLSP_Participants/GMU/multilex_test_fil_ls_A1.tsv	GMU	Filipino	1	0.056200	0.063200	0.068500	0.293400	0.398900	0.435800	0.486800	0.139500	0.091600	0.049100
# MLSP_Participants/GMU/multilex_test_fil_ls_A2.tsv	GMU	Filipino	2	0.014000	0.021000	0.022800	0.072000	0.173900	0.254800	0.351400	0.042000	0.031400	0.018900
# MLSP_Participants/GMU/multilex_test_fil_ls_2.tsv	GMU	Filipino	2	0.015700	0.022800	0.024500	0.080700	0.184200	0.285900	0.385900	0.044900	0.033800	0.020100
# MLSP_Participants/GMU/multilex_test_fil_ls_1.tsv	GMU	Filipino	1	0.056100	0.063100	0.068400	0.292900	0.398200	0.435000	0.485900	0.139200	0.091400	0.049100
# MLSP_Participants/TMU-HIT/multilex_test_fil_ls_A1.tsv	TMU-HIT	Filipino	1	0.065000	0.084300	0.087800	0.365500	0.509600	0.560600	0.606300	0.180700	0.118900	0.064200
# MLSP_Participants/TMU-HIT/multilex_test_fil_ls_A2.tsv	TMU-HIT	Filipino	2	0.061500	0.077300	0.087800	0.332100	0.509600	0.560600	0.606300	0.173600	0.114700	0.062100
# MLSP_Participants/TMU-HIT/multilex_test_fil_ls_A3.tsv	TMU-HIT	Filipino	3	0.040400	0.070200	0.087800	0.270600	0.509600	0.560600	0.606300	0.159200	0.106100	0.057800
# MLSP_Participants/RETUYT-INCO/multilex_test_fil_ls_A1.tsv	RETUYT-INCO	Filipino	1	0.008700	0.008700	0.008700	0.036900	0.052700	0.057900	0.065000	0.015400	0.009400	0.004800
# MLSP_Participants/RETUYT-INCO/multilex_test_fil_ls_A2.tsv	RETUYT-INCO	Filipino	2	0.007000	0.008700	0.008700	0.021000	0.028100	0.033300	0.054400	0.008200	0.005100	0.002800
# MLSP_Participants/Archaeology/multilex_test_fr_ls_1.tsv	Archaeology	French	1	0.065000	0.105400	0.126500	0.170400	0.328600	0.423500	0.523700	0.104400	0.081900	0.054000
# MLSP_Participants/Archaeology/multilex_test_fr_ls_2.tsv	Archaeology	French	2	0.072000	0.126500	0.170400	0.200300	0.425300	0.562300	0.667800	0.144700	0.121000	0.086400
# MLSP_Participants/Baseline/multilex_test_fr_ls.tsv	Baseline	French	s	0.295200	0.356700	0.376000	0.592200	0.741600	0.778500	0.811900	0.367400	0.262600	0.150500
# MLSP_Participants/GMU/multilex_test_fr_ls_1.tsv	GMU	French	1	0.365500	0.455100	0.513100	0.739800	0.868100	0.889200	0.915600	0.514100	0.394000	0.244500
# MLSP_Participants/GMU/multilex_test_fr_ls_2.tsv	GMU	French	2	0.084300	0.177500	0.253000	0.235500	0.572900	0.743400	0.887500	0.188000	0.164500	0.108000
# MLSP_Participants/GMU/multilex_test_fr_ls_A1.tsv	GMU	French	1	0.366100	0.455900	0.514000	0.741100	0.867900	0.889000	0.915400	0.514800	0.394600	0.244700
# MLSP_Participants/GMU/multilex_test_fr_ls_A2.tsv	GMU	French	2	0.084500	0.167200	0.239400	0.227100	0.531600	0.697100	0.825700	0.172500	0.149000	0.102300
# MLSP_Participants/TMU-HIT/multilex_test_fr_ls_A1.tsv	TMU-HIT	French	1	0.426000	0.566900	0.619700	0.855600	0.961200	0.973500	0.985900	0.697700	0.546600	0.335800
# MLSP_Participants/TMU-HIT/multilex_test_fr_ls_A2.tsv	TMU-HIT	French	2	0.424200	0.544000	0.619700	0.846800	0.961200	0.973500	0.985900	0.694000	0.544300	0.334700
# MLSP_Participants/TMU-HIT/multilex_test_fr_ls_A3.tsv	TMU-HIT	French	3	0.325700	0.508800	0.619700	0.795700	0.961200	0.973500	0.985900	0.681500	0.536800	0.330900
# MLSP_Participants/RETUYT-INCO/multilex_test_fr_ls_A1.tsv	RETUYT-INCO	French	1	0.301000	0.406600	0.455900	0.589700	0.758800	0.801000	0.832700	0.397400	0.275400	0.149800
# MLSP_Participants/RETUYT-INCO/multilex_test_fr_ls_A2.tsv	RETUYT-INCO	French	2	0.276400	0.380200	0.427800	0.582700	0.730600	0.786900	0.829200	0.377600	0.266200	0.142700
# MLSP_Participants/ISEP_Presidency_University/multilex_test_fr_ls_1.tsv	ISEP_Presidency_University	French	1	0.374300	0.509600	0.571100	0.831200	0.933200	0.956000	0.973600	0.648400	0.499600	0.307500
# MLSP_Participants/Archaeology/multilex_test_de_ls_2.tsv	Archaeology	German	2	0.028000	0.057800	0.077100	0.056100	0.149100	0.182400	0.231500	0.038800	0.029400	0.017300
# MLSP_Participants/Archaeology/multilex_test_de_ls_1.tsv	Archaeology	German	1	0.061400	0.096400	0.114000	0.098200	0.217500	0.298200	0.392900	0.062600	0.048400	0.028700
# MLSP_Participants/Baseline/multilex_test_de_ls.tsv	Baseline	German	s	0.171900	0.214000	0.219200	0.303500	0.352600	0.368400	0.396400	0.156200	0.105400	0.056800
# MLSP_Participants/GMU/multilex_test_de_ls_A1.tsv	GMU	German	1	0.420000	0.504300	0.581700	0.641400	0.790800	0.831200	0.855800	0.400200	0.287400	0.163100
# MLSP_Participants/GMU/multilex_test_de_ls_A2.tsv	GMU	German	2	0.112400	0.212600	0.286400	0.247800	0.521900	0.644900	0.773200	0.178400	0.138700	0.086600
# MLSP_Participants/GMU/multilex_test_de_ls_2.tsv	GMU	German	2	0.119200	0.222800	0.300000	0.257800	0.549100	0.666600	0.798200	0.185200	0.146300	0.092000
# MLSP_Participants/GMU/multilex_test_de_ls_1.tsv	GMU	German	1	0.419200	0.503500	0.582400	0.642100	0.791200	0.831500	0.856100	0.400400	0.287400	0.163200
# MLSP_Participants/TMU-HIT/multilex_test_de_ls_A1.tsv	TMU-HIT	German	1	0.488500	0.611500	0.669500	0.741600	0.876900	0.903300	0.926100	0.488200	0.354800	0.204600
# MLSP_Participants/TMU-HIT/multilex_test_de_ls_A3.tsv	TMU-HIT	German	3	0.355000	0.560600	0.669500	0.627400	0.876900	0.903300	0.926100	0.463300	0.339800	0.197200
# MLSP_Participants/TMU-HIT/multilex_test_de_ls_A2.tsv	TMU-HIT	German	2	0.441100	0.592200	0.669500	0.704700	0.876900	0.903300	0.926100	0.481000	0.350400	0.202500
# MLSP_Participants/RETUYT-INCO/multilex_test_de_ls_A1.tsv	RETUYT-INCO	German	1	0.302200	0.383100	0.434000	0.478000	0.608000	0.660800	0.718800	0.269900	0.178700	0.096500
# MLSP_Participants/RETUYT-INCO/multilex_test_de_ls_A2.tsv	RETUYT-INCO	German	2	0.267100	0.367300	0.416500	0.449900	0.613300	0.655500	0.708200	0.262600	0.176500	0.094400
# MLSP_Participants/ISEP_Presidency_University/multilex_test_de_ls_1.tsv	ISEP_Presidency_University	German	1	0.218700	0.250000	0.250000	0.302000	0.354100	0.364500	0.416600	0.198400	0.134400	0.084100
# MLSP_Participants/Archaeology/multilex_test_it_ls_2.tsv	Archaeology	Italian	2	0.094700	0.140300	0.192900	0.178900	0.350800	0.464900	0.561400	0.114500	0.092000	0.058900
# MLSP_Participants/Archaeology/multilex_test_it_ls_1.tsv	Archaeology	Italian	1	0.049100	0.103500	0.150800	0.149100	0.338500	0.428000	0.500000	0.097500	0.075500	0.047200
# MLSP_Participants/Baseline/multilex_test_it_ls.tsv	Baseline	Italian	s	0.296400	0.407000	0.468400	0.545600	0.680700	0.724500	0.778900	0.331000	0.225400	0.123200
# MLSP_Participants/GMU/multilex_test_it_ls_2.tsv	GMU	Italian	2	0.085900	0.187700	0.277100	0.208700	0.528000	0.701700	0.828000	0.163900	0.136200	0.085400
# MLSP_Participants/GMU/multilex_test_it_ls_1.tsv	GMU	Italian	1	0.403500	0.563100	0.631500	0.735000	0.882400	0.924500	0.940300	0.461600	0.332800	0.196600
# MLSP_Participants/GMU/multilex_test_it_ls_A2.tsv	GMU	Italian	2	0.154600	0.272400	0.356700	0.356700	0.662500	0.785500	0.871700	0.246000	0.196500	0.124200
# MLSP_Participants/GMU/multilex_test_it_ls_A1.tsv	GMU	Italian	1	0.404200	0.564100	0.630900	0.734600	0.882200	0.924400	0.940200	0.461500	0.332800	0.196600
# MLSP_Participants/TMU-HIT/multilex_test_it_ls_A2.tsv	TMU-HIT	Italian	2	0.465700	0.616800	0.718800	0.768000	0.938400	0.957800	0.977100	0.558000	0.407800	0.247200
# MLSP_Participants/TMU-HIT/multilex_test_it_ls_A3.tsv	TMU-HIT	Italian	3	0.370800	0.590500	0.718800	0.720500	0.938400	0.957800	0.977100	0.545400	0.400200	0.243500
# MLSP_Participants/TMU-HIT/multilex_test_it_ls_A1.tsv	TMU-HIT	Italian	1	0.476200	0.625600	0.718800	0.803100	0.938400	0.957800	0.977100	0.566100	0.412600	0.249600
# MLSP_Participants/RETUYT-INCO/multilex_test_it_ls_A2.tsv	RETUYT-INCO	Italian	2	0.302200	0.428800	0.485000	0.523700	0.715200	0.762700	0.806600	0.330500	0.225300	0.121900
# MLSP_Participants/RETUYT-INCO/multilex_test_it_ls_A1.tsv	RETUYT-INCO	Italian	1	0.316300	0.446300	0.497300	0.551800	0.736300	0.778500	0.818900	0.351100	0.243400	0.133500
# MLSP_Participants/ISEP_Presidency_University/multilex_test_it_ls_1.tsv	ISEP_Presidency_University	Italian	1	0.424500	0.600000	0.661400	0.743800	0.896400	0.943800	0.966600	0.506400	0.378800	0.224300
# MLSP_Participants/Archaeology/multilex_test_ja_ls_2.tsv	Archaeology	Japanese	2	0.036800	0.068400	0.092900	0.092900	0.228000	0.307000	0.387700	0.059200	0.044100	0.027700
# MLSP_Participants/Archaeology/multilex_test_ja_ls_1.tsv	Archaeology	Japanese	1	0.026300	0.061400	0.082400	0.073600	0.205200	0.275400	0.378900	0.051600	0.039100	0.024000
# MLSP_Participants/Baseline/multilex_test_ja_ls.tsv	Baseline	Japanese	s	0.156100	0.214000	0.242100	0.321000	0.443800	0.475400	0.508700	0.173500	0.117300	0.064700
# MLSP_Participants/GMU/multilex_test_ja_ls_A2.tsv	GMU	Japanese	2	0.119500	0.214400	0.284700	0.307500	0.581700	0.673100	0.746900	0.214400	0.171000	0.110700
# MLSP_Participants/GMU/multilex_test_ja_ls_A1.tsv	GMU	Japanese	1	0.258300	0.370800	0.439300	0.541300	0.680100	0.722300	0.762700	0.361800	0.259900	0.152900
# MLSP_Participants/GMU/multilex_test_ja_ls_2.tsv	GMU	Japanese	2	0.021000	0.049100	0.091200	0.078900	0.273600	0.421000	0.614000	0.068100	0.060500	0.048600
# MLSP_Participants/GMU/multilex_test_ja_ls_1.tsv	GMU	Japanese	1	0.257800	0.370100	0.438500	0.540300	0.678900	0.721000	0.761400	0.361200	0.259500	0.152600
# MLSP_Participants/TMU-HIT/multilex_test_ja_ls_A2.tsv	TMU-HIT	Japanese	2	0.381300	0.518400	0.576400	0.674800	0.854100	0.899800	0.940200	0.477600	0.352200	0.216300
# MLSP_Participants/TMU-HIT/multilex_test_ja_ls_A3.tsv	TMU-HIT	Japanese	3	0.325100	0.474500	0.576400	0.650200	0.854100	0.899800	0.940200	0.470600	0.348000	0.214200
# MLSP_Participants/TMU-HIT/multilex_test_ja_ls_A1.tsv	TMU-HIT	Japanese	1	0.398900	0.513100	0.576400	0.722300	0.854100	0.899800	0.940200	0.488100	0.358600	0.219500
# MLSP_Participants/TMU-HIT/multilex_test_ja_ls_3.tsv	TMU-HIT	Japanese	3	0.326300	0.475400	0.577100	0.650800	0.854300	0.900000	0.940300	0.470700	0.348300	0.214200
# MLSP_Participants/TMU-HIT/multilex_test_ja_ls_2.tsv	TMU-HIT	Japanese	2	0.382400	0.519200	0.577100	0.675400	0.854300	0.900000	0.940300	0.477900	0.352600	0.216400
# MLSP_Participants/TMU-HIT/multilex_test_ja_ls_1.tsv	TMU-HIT	Japanese	1	0.400000	0.514000	0.577100	0.722800	0.854300	0.900000	0.940300	0.488300	0.358800	0.219500
# MLSP_Participants/RETUYT-INCO/multilex_test_ja_ls_A2.tsv	RETUYT-INCO	Japanese	2	0.087800	0.123000	0.140500	0.202100	0.286400	0.325100	0.351400	0.094900	0.060700	0.031200
# MLSP_Participants/RETUYT-INCO/multilex_test_ja_ls_A1.tsv	RETUYT-INCO	Japanese	1	0.094900	0.123000	0.137000	0.214400	0.309300	0.342700	0.377800	0.102600	0.066500	0.034600
# MLSP_Participants/Archaeology/multilex_test_pt_ls_1.tsv	Archaeology	Portuguese	1	0.086400	0.148100	0.211600	0.137500	0.301500	0.417900	0.560800	0.079000	0.057400	0.034200
# MLSP_Participants/Archaeology/multilex_test_pt_ls_2.tsv	Archaeology	Portuguese	2	0.097000	0.167500	0.253900	0.151600	0.352700	0.486700	0.589000	0.092000	0.070400	0.041000
# MLSP_Participants/Baseline/multilex_test_pt_ls.tsv	Baseline	Portuguese	s	0.350900	0.449700	0.497300	0.465600	0.613700	0.680700	0.721300	0.233000	0.151600	0.080300
# MLSP_Participants/GMU/multilex_test_pt_ls_A1.tsv	GMU	Portuguese	1	0.437900	0.553100	0.620500	0.585100	0.748200	0.812000	0.856300	0.303800	0.202700	0.109900
# MLSP_Participants/GMU/multilex_test_pt_ls_A2.tsv	GMU	Portuguese	2	0.210900	0.336800	0.441400	0.324400	0.576200	0.703900	0.801400	0.192400	0.140200	0.079200
# MLSP_Participants/GMU/multilex_test_pt_ls_1.tsv	GMU	Portuguese	1	0.433800	0.550200	0.619000	0.582000	0.746000	0.809500	0.853600	0.303700	0.202500	0.109800
# MLSP_Participants/GMU/multilex_test_pt_ls_2.tsv	GMU	Portuguese	2	0.121600	0.225700	0.313900	0.185100	0.449700	0.620800	0.747700	0.117000	0.092800	0.054300
# MLSP_Participants/TMU-HIT/multilex_test_pt_ls_A1.tsv	TMU-HIT	Portuguese	1	0.443200	0.586800	0.659500	0.601000	0.797800	0.838600	0.886500	0.345100	0.228500	0.124500
# MLSP_Participants/TMU-HIT/multilex_test_pt_ls_A2.tsv	TMU-HIT	Portuguese	2	0.409500	0.569100	0.659500	0.556700	0.797800	0.838600	0.886500	0.334100	0.221900	0.121200
# MLSP_Participants/TMU-HIT/multilex_test_pt_ls_A3.tsv	TMU-HIT	Portuguese	3	0.377600	0.553100	0.659500	0.533600	0.797800	0.838600	0.886500	0.329700	0.219300	0.119900
# MLSP_Participants/RETUYT-INCO/multilex_test_pt_ls_A1.tsv	RETUYT-INCO	Portuguese	1	0.274800	0.382900	0.450300	0.400700	0.578000	0.613400	0.663100	0.208800	0.135600	0.071100
# MLSP_Participants/RETUYT-INCO/multilex_test_pt_ls_A2.tsv	RETUYT-INCO	Portuguese	2	0.260600	0.356300	0.420200	0.377600	0.542500	0.586800	0.618700	0.207000	0.134100	0.069700
# MLSP_Participants/RETUYT-INCO/multilex_test_pt_ls_1.tsv	RETUYT-INCO	Portuguese	1	0.058200	0.093400	0.135800	0.067000	0.160400	0.192200	0.220400	0.038000	0.025100	0.013600
# MLSP_Participants/RETUYT-INCO/multilex_test_pt_ls_2.tsv	RETUYT-INCO	Portuguese	2	0.276800	0.384400	0.451400	0.402100	0.578400	0.613700	0.663100	0.209400	0.136000	0.071200
# MLSP_Participants/RETUYT-INCO/multilex_test_pt_ls_3.tsv	RETUYT-INCO	Portuguese	3	0.259200	0.356200	0.419700	0.375600	0.541400	0.585500	0.617200	0.206200	0.133600	0.069500
# MLSP_Participants/ISEP_Presidency_University/multilex_test_pt_ls_1.tsv	ISEP_Presidency_University	Portuguese	1	0.485000	0.617200	0.668400	0.633100	0.804200	0.857100	0.911800	0.353800	0.242100	0.133500
# MLSP_Participants/ANU/multilex_test_si_ls_1.tsv	ANU	Sinhala	1	0.013300	0.015000	0.016600	0.013300	0.018300	0.020000	0.021600	0.007400	0.004500	0.002300
# MLSP_Participants/Archaeology/multilex_test_si_ls_1.tsv	Archaeology	Sinhala	1	0.046600	0.063300	0.078300	0.066600	0.138300	0.178300	0.236600	0.035900	0.024200	0.013100
# MLSP_Participants/Archaeology/multilex_test_si_ls_2.tsv	Archaeology	Sinhala	2	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000
# MLSP_Participants/Baseline/multilex_test_si_ls.tsv	Baseline	Sinhala	s	0.000000	0.001600	0.003300	0.005000	0.011600	0.011600	0.015000	0.002800	0.001700	0.000900
# MLSP_Participants/GMU/multilex_test_si_ls_1.tsv	GMU	Sinhala	1	0.228300	0.286600	0.320000	0.311600	0.418300	0.483300	0.536600	0.140000	0.090200	0.047300
# MLSP_Participants/GMU/multilex_test_si_ls_A2.tsv	GMU	Sinhala	2	0.130000	0.237200	0.305700	0.195000	0.384800	0.463900	0.527200	0.114700	0.075900	0.039400
# MLSP_Participants/GMU/multilex_test_si_ls_2.tsv	GMU	Sinhala	2	0.125000	0.230000	0.306600	0.190000	0.391600	0.481600	0.556600	0.116800	0.078000	0.041200
# MLSP_Participants/GMU/multilex_test_si_ls_A1.tsv	GMU	Sinhala	1	0.228400	0.282900	0.316300	0.311000	0.416500	0.481500	0.536000	0.138700	0.089400	0.046900
# MLSP_Participants/TMU-HIT/multilex_test_si_ls_A2.tsv	TMU-HIT	Sinhala	2	0.221400	0.328600	0.358500	0.319800	0.490300	0.546500	0.623900	0.167300	0.108000	0.058300
# MLSP_Participants/TMU-HIT/multilex_test_si_ls_A3.tsv	TMU-HIT	Sinhala	3	0.119500	0.275900	0.358500	0.224900	0.490300	0.546500	0.623900	0.146900	0.095700	0.052200
# MLSP_Participants/TMU-HIT/multilex_test_si_ls_A1.tsv	TMU-HIT	Sinhala	1	0.214400	0.304000	0.358500	0.344400	0.490300	0.546500	0.623900	0.170900	0.110100	0.059400
# MLSP_Participants/RETUYT-INCO/multilex_test_si_ls_A2.tsv	RETUYT-INCO	Sinhala	2	0.000000	0.000000	0.000000	0.008700	0.010500	0.010500	0.012300	0.003200	0.001900	0.000900
# MLSP_Participants/RETUYT-INCO/multilex_test_si_ls_A1.tsv	RETUYT-INCO	Sinhala	1	0.001700	0.001700	0.001700	0.012300	0.012300	0.012300	0.012300	0.004100	0.002400	0.001200
# MLSP_Participants/Archaeology/multilex_test_es_ls_1.tsv	Archaeology	Spanish	1	0.045500	0.075800	0.111200	0.138200	0.311900	0.419800	0.549700	0.095100	0.075600	0.051900
# MLSP_Participants/Archaeology/multilex_test_es_ls_2.tsv	Archaeology	Spanish	2	0.067400	0.129800	0.173600	0.227600	0.414800	0.514300	0.630600	0.156500	0.129200	0.090700
# MLSP_Participants/Baseline/multilex_test_es_ls.tsv	Baseline	Spanish	s	0.325400	0.419800	0.451900	0.618800	0.763900	0.790800	0.807700	0.415700	0.301900	0.170700
# MLSP_Participants/GMU/multilex_test_es_ls_A1.tsv	GMU	Spanish	1	0.416500	0.532800	0.605300	0.797600	0.912300	0.942600	0.956100	0.594800	0.462700	0.283400
# MLSP_Participants/GMU/multilex_test_es_ls_A2.tsv	GMU	Spanish	2	0.236000	0.355800	0.470400	0.591900	0.860000	0.910600	0.939200	0.437100	0.354200	0.224400
# MLSP_Participants/GMU/multilex_test_es_ls_1.tsv	GMU	Spanish	1	0.418200	0.536200	0.608700	0.801000	0.917300	0.947700	0.961200	0.598700	0.465300	0.285300
# MLSP_Participants/GMU/multilex_test_es_ls_2.tsv	GMU	Spanish	2	0.089300	0.207400	0.290000	0.268100	0.642400	0.811100	0.900500	0.217000	0.188200	0.117200
# MLSP_Participants/TMU-HIT/multilex_test_es_ls_A1.tsv	TMU-HIT	Spanish	1	0.453600	0.575000	0.652600	0.846500	0.934200	0.946000	0.962900	0.676300	0.527600	0.326800
# MLSP_Participants/TMU-HIT/multilex_test_es_ls_A3.tsv	TMU-HIT	Spanish	3	0.364200	0.536200	0.652600	0.777400	0.934200	0.946000	0.962900	0.659200	0.517400	0.321700
# MLSP_Participants/TMU-HIT/multilex_test_es_ls_A2.tsv	TMU-HIT	Spanish	2	0.450200	0.554800	0.652600	0.843100	0.934200	0.946000	0.962900	0.672100	0.525100	0.325600
# MLSP_Participants/RETUYT-INCO/multilex_test_es_ls_A1.tsv	RETUYT-INCO	Spanish	1	0.318700	0.430000	0.495700	0.603700	0.801000	0.831300	0.861700	0.407500	0.287900	0.156700
# MLSP_Participants/RETUYT-INCO/multilex_test_es_ls_A2.tsv	RETUYT-INCO	Spanish	2	0.306900	0.423200	0.468800	0.596900	0.777400	0.806000	0.839700	0.399000	0.278900	0.151800
# MLSP_Participants/RETUYT-INCO/multilex_test_es_ls_1.tsv	RETUYT-INCO	Spanish	1	0.107900	0.155100	0.185400	0.256300	0.409700	0.490700	0.598600	0.154000	0.119300	0.073100
# MLSP_Participants/RETUYT-INCO/multilex_test_es_ls_3.tsv	RETUYT-INCO	Spanish	3	0.328800	0.443500	0.483900	0.613800	0.787500	0.824600	0.853200	0.412400	0.298000	0.159500
# MLSP_Participants/RETUYT-INCO/multilex_test_es_ls_2.tsv	RETUYT-INCO	Spanish	2	0.104500	0.190500	0.269800	0.313600	0.613800	0.770600	0.836400	0.231300	0.194700	0.116900

# %%
#ALL files

gold = "MLSP_Organisers/Gold/All/multilex_test_all_ls_labels.tsv"
sys_files = glob.glob("MLSP_Participants/*/multilex_test_all_combined_ls*")
stop_on_error = True

for output_file in sys_files:
    try:
        call_ls_evaluate(gold,output_file,False,"All")
    except Exception as exception:
        if stop_on_error:
            print(gold)
            print(output_file)
            raise exception
        else:
            print(output_file +"\t could not parse")
# Out:
# MLSP_Participants/Archaeology/multilex_test_all_combined_ls_A.tsv	Archaeology	All	A	0.053800	0.096900	0.134000	0.131400	0.276400	0.360000	0.446400	0.088200	0.071300	0.047300
# MLSP_Participants/dummy1/multilex_test_all_combined_ls_1.tsv	dummy1	All	1	0.000000	0.000000	0.000100	0.000300	0.001200	0.001900	0.003200	0.000200	0.000100	0.000100
# MLSP_Participants/GMU/multilex_test_all_combined_ls_1.tsv	GMU	All	1	0.334500	0.429100	0.482800	0.593400	0.727600	0.769500	0.803000	0.379000	0.275400	0.161400
# MLSP_Participants/GMU/multilex_test_all_combined_ls_2.tsv	GMU	All	2	0.133100	0.226100	0.299900	0.287600	0.537400	0.646700	0.738600	0.198100	0.156100	0.097100
# MLSP_Participants/TMU-HIT/multilex_test_all_combined_ls_1.tsv	TMU-HIT	All	1	0.377200	0.491900	0.549800	0.673900	0.807100	0.840700	0.875900	0.465200	0.342100	0.202600
# MLSP_Participants/TMU-HIT/multilex_test_all_combined_ls_2.tsv	TMU-HIT	All	2	0.357300	0.479200	0.549800	0.639100	0.807100	0.840700	0.875900	0.457000	0.337100	0.200100
# MLSP_Participants/TMU-HIT/multilex_test_all_combined_ls_3.tsv	TMU-HIT	All	3	0.293300	0.455400	0.549800	0.591800	0.807100	0.840700	0.875900	0.446100	0.330600	0.196900
# MLSP_Participants/RETUYT-INCO/multilex_test_all_combined_ls_1.tsv	RETUYT-INCO	All	1	0.215600	0.291200	0.332400	0.392500	0.523300	0.556000	0.589300	0.241200	0.165000	0.089000
# MLSP_Participants/RETUYT-INCO/multilex_test_all_combined_ls_2.tsv	RETUYT-INCO	All	2	0.207400	0.285100	0.321600	0.381800	0.509100	0.543600	0.577200	0.235100	0.160800	0.086200
