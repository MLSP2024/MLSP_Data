# %%
#!/usr/bin/env python3
import csv
import glob
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from scipy.stats import pearsonr, spearmanr

# %%
#cherry_pick is used to read specific ids from an all file (e.g., to assess only one lang)
def evaluate(submission, reference_file, verbose, cherry_pick=None):
    #Read predictions:
    submission_dict = {}
    with open(submission, 'r') as sf:
        csv_reader = csv.reader(sf, delimiter="\t")
        for item in csv_reader:
            if cherry_pick:
                if item[0].startswith(cherry_pick):
                    submission_dict[item[0]] = float(item[4])
            else:
                submission_dict[item[0]] = float(item[4])

            
    #Read reference:
    gold_dict = {}
    with open(reference_file, 'r') as rf:
        csv_reader = csv.reader(rf, delimiter="\t")
        for item in csv_reader:
            if cherry_pick:
                if item[0].startswith(cherry_pick):
                    gold_dict[item[0]] = float(item[4])
            else:
                gold_dict[item[0]] = float(item[4])

    remove_ids = ["fr_150","fr_513","pt_600","pt_579"]

    for remove_id in remove_ids:
        try:
            submission_dict.pop(remove_id)
        except:
            pass
        
        try:
            gold_dict.pop(remove_id)
        except:
            pass

    if verbose == 3:
        print(submission_dict.keys())

    #Produce vectors with reference labels and predictions:
    gold = []
    predicted = []

    for key, label in gold_dict.items():
        gold.append(label)
        predicted.append(submission_dict[key])


    if verbose > 0:
        gold_len = len(gold_dict.keys())
        sub_len = len(submission_dict.keys())
        both_len = len(gold_dict.keys() & submission_dict.keys())

        if gold_len != sub_len:
            print("different ids in gold and sub")

        if gold_len != both_len:
            print("check ids: Gold")

        if sub_len != both_len:
            print("check ids: Sub")
                
        if verbose == 2:
            bad_keys = gold_dict.keys() ^ submission_dict.keys()
            if len(bad_keys) != 0:
                raise  Exception("Bad Keys: " + str(bad_keys))
        
        

    #Calculate scores:
    pearson_score = pearsonr(gold, predicted)[0]
    spearman_score = spearmanr(gold, predicted)[0]
    mae_score = mean_absolute_error(gold, predicted)
    mse_score = mean_squared_error(gold, predicted)
    rsq_score = r2_score(gold, predicted)
    
    return (pearson_score, spearman_score, mae_score, mse_score, rsq_score)

# %%
#verbose = 0 - no errors
#        = 1 - notify errors + continue
#        = 2 - explain errors + fail
def process_lang(gold, sys_files, lang, verbose=1, cherry_pick=None):
    for output in sys_files:
        if verbose >= 2:
            print(gold)
            print(output)
        try:
            results = evaluate(output,gold,verbose)
        except Exception as error:
            if verbose == 0:
                continue
            elif verbose == 1:
                print("Failed on " + output)
                continue
            else:
                raise error                
        parts = output.split("/")
        print("%s\t%s\t%s\t%s\t%f\t%f\t%f\t%f\t%f" % ((output, parts[1], lang, parts[2][-5]) + results))

# %%
lang_ids = ["ca","en","fil","fr","de","it","ja","pt","si","es"]
lang_dict = {"ca":"Catalan", 
             "en":"English",
             "fil":"Filipino",
             "fr":"French",
             "de":"German",
             "it":"Italian",
             "ja":"Japanese",
             "pt":"Portuguese",
             "si":"Sinhala",
             "es":"Spanish"}

def process_lang_all(gold, sys_files, verbose=1):
    
    for output in sys_files:
        if verbose >= 2:
            print(gold)
            print(output)
        for lang_id in lang_ids:
            try:
                results = evaluate(output,gold,verbose,lang_id)
            except Exception as error:
                if verbose == 0:
                    continue
                elif verbose == 1:
                    print("Failed on " + output)
                    continue
                else:
                    raise error                
            parts = output.split("/")
            print("%s\t%s\t%s\t%s\t%f\t%f\t%f\t%f\t%f" % ((output, parts[1], lang_dict[lang_id], "A") + results))

# %%
def call_process_lang(name1,name2,abbrv):
    gold = "MLSP_Organisers/Gold/" + name1 + "/multilex_test_" + name2 + "_lcp_labels.tsv"
    sys_files = glob.glob("MLSP_Participants/*/multilex_test_" + abbrv + "_lcp*")
    process_lang(gold,sys_files,name1)

# %%
call_process_lang("Catalan"   , "catalan",    "ca")
call_process_lang("English"   , "english",    "en")
call_process_lang("Filipino"  , "filipino",   "fil")
call_process_lang("French"    , "french",     "fr")
call_process_lang("German"    , "german",     "de")
call_process_lang("Italian"   , "italian",    "it")
call_process_lang("Japanese"  , "japanese",   "ja")
call_process_lang("Portuguese", "portuguese", "pt")
call_process_lang("Sinhala"   , "sinhala",    "si")
call_process_lang("Spanish"   , "spanish",    "es")
call_process_lang("All"       , "all",        "all_combined")

all_gold = "MLSP_Organisers/Gold/All/multilex_test_all_lcp_labels.tsv"
all_sys_files = glob.glob("MLSP_Participants/*/multilex_test_all_combined_lcp*")

process_lang_all(all_gold, all_sys_files)
# Out:
# MLSP_Participants/Archaeology/Extra/full_mt/multilex_test_ca_lcp_5.tsv	Archaeology	Catalan	E	0.154346	0.127678	0.211199	0.063610	-1.678674
# MLSP_Participants/Archaeology/Extra/base_mt/multilex_test_ca_lcp_3.tsv	Archaeology	Catalan	E	0.243333	0.200048	0.186026	0.050979	-1.146786
# MLSP_Participants/Archaeology/Extra/full_orig/multilex_test_ca_lcp_6.tsv	Archaeology	Catalan	E	0.272141	0.277575	0.126424	0.024330	-0.024579
# MLSP_Participants/Archaeology/Extra/base_orig/multilex_test_ca_lcp_4.tsv	Archaeology	Catalan	E	0.294091	0.292113	0.125561	0.024036	-0.012164
# MLSP_Participants/Archaeology/Extra/full_orig/multilex_test_en_lcp_6.tsv	Archaeology	English	E	0.507326	0.552056	0.122099	0.029520	0.196450
# MLSP_Participants/Archaeology/Extra/base_orig/multilex_test_en_lcp_4.tsv	Archaeology	English	E	0.337010	0.243006	0.137923	0.034341	0.065213
# MLSP_Participants/Archaeology/Extra/full_mt/multilex_test_fil_lcp_5.tsv	Archaeology	Filipino	E	0.170322	0.200824	0.152792	0.039501	-0.817912
# MLSP_Participants/Archaeology/Extra/base_mt/multilex_test_fil_lcp_3.tsv	Archaeology	Filipino	E	0.119194	0.111395	0.118012	0.022885	-0.053201
# MLSP_Participants/Archaeology/Extra/full_orig/multilex_test_fil_lcp_6.tsv	Archaeology	Filipino	E	0.399520	0.434512	0.139525	0.028658	-0.318863
# MLSP_Participants/Archaeology/Extra/base_orig/multilex_test_fil_lcp_4.tsv	Archaeology	Filipino	E	0.370505	0.396385	0.159092	0.035817	-0.648342
# MLSP_Participants/Archaeology/Extra/full_mt/multilex_test_fr_lcp_5.tsv	Archaeology	French	E	0.178471	0.136822	0.216564	0.087300	-0.409368
# MLSP_Participants/Archaeology/Extra/base_mt/multilex_test_fr_lcp_3.tsv	Archaeology	French	E	0.089468	0.090577	0.202682	0.072120	-0.164300
# MLSP_Participants/Archaeology/Extra/full_orig/multilex_test_fr_lcp_6.tsv	Archaeology	French	E	0.507726	0.502782	0.178938	0.046882	0.243141
# MLSP_Participants/Archaeology/Extra/base_orig/multilex_test_fr_lcp_4.tsv	Archaeology	French	E	0.551255	0.561011	0.180337	0.045858	0.259666
# MLSP_Participants/Archaeology/Extra/full_mt/multilex_test_de_lcp_5.tsv	Archaeology	German	E	0.158362	0.182510	0.313923	0.129138	-3.779821
# MLSP_Participants/Archaeology/Extra/base_mt/multilex_test_de_lcp_3.tsv	Archaeology	German	E	0.102695	0.122510	0.285583	0.108000	-2.997439
# MLSP_Participants/Archaeology/Extra/full_orig/multilex_test_de_lcp_6.tsv	Archaeology	German	E	0.552605	0.575431	0.133817	0.029424	-0.089073
# MLSP_Participants/Archaeology/Extra/base_orig/multilex_test_de_lcp_4.tsv	Archaeology	German	E	0.552184	0.568937	0.128353	0.027524	-0.018739
# MLSP_Participants/Archaeology/Extra/full_mt/multilex_test_it_lcp_5.tsv	Archaeology	Italian	E	0.299370	0.309153	0.148348	0.038020	-0.353931
# MLSP_Participants/Archaeology/Extra/base_mt/multilex_test_it_lcp_3.tsv	Archaeology	Italian	E	0.100558	0.104074	0.132846	0.031243	-0.112590
# MLSP_Participants/Archaeology/Extra/full_orig/multilex_test_it_lcp_6.tsv	Archaeology	Italian	E	0.509115	0.511245	0.146236	0.031786	-0.131925
# MLSP_Participants/Archaeology/Extra/base_orig/multilex_test_it_lcp_4.tsv	Archaeology	Italian	E	0.526194	0.537992	0.159476	0.036067	-0.284371
# MLSP_Participants/Archaeology/Extra/full_mt/multilex_test_ja_lcp_5.tsv	Archaeology	Japanese	E	0.038864	0.067513	0.181906	0.053068	-0.920658
# MLSP_Participants/Archaeology/Extra/base_mt/multilex_test_ja_lcp_3.tsv	Archaeology	Japanese	E	0.025634	0.019072	0.142370	0.031674	-0.146358
# MLSP_Participants/Archaeology/Extra/full_orig/multilex_test_ja_lcp_6.tsv	Archaeology	Japanese	E	0.501900	0.538422	0.141191	0.029513	-0.068139
# MLSP_Participants/Archaeology/Extra/base_orig/multilex_test_ja_lcp_4.tsv	Archaeology	Japanese	E	0.259645	0.229939	0.259038	0.086435	-2.128324
# MLSP_Participants/Archaeology/Extra/full_mt/multilex_test_pt_lcp_5.tsv	Archaeology	Portuguese	E	0.426880	0.446644	0.122814	0.026359	-0.206013
# MLSP_Participants/Archaeology/Extra/base_mt/multilex_test_pt_lcp_3.tsv	Archaeology	Portuguese	E	0.232671	0.209337	0.117780	0.021906	-0.002298
# MLSP_Participants/Archaeology/Extra/full_orig/multilex_test_pt_lcp_6.tsv	Archaeology	Portuguese	E	0.715366	0.714075	0.109357	0.017132	0.216137
# MLSP_Participants/Archaeology/Extra/base_orig/multilex_test_pt_lcp_4.tsv	Archaeology	Portuguese	E	0.724895	0.727369	0.127972	0.022008	-0.006930
# MLSP_Participants/Archaeology/Extra/full_mt/multilex_test_si_lcp_5.tsv	Archaeology	Sinhala	E	0.100230	0.065891	0.122526	0.028593	-0.765490
# MLSP_Participants/Archaeology/Extra/base_mt/multilex_test_si_lcp_3.tsv	Archaeology	Sinhala	E	0.076824	0.045210	0.100495	0.016582	-0.023867
# MLSP_Participants/Archaeology/Extra/full_orig/multilex_test_si_lcp_6.tsv	Archaeology	Sinhala	E	0.049131	0.033379	0.127662	0.023364	-0.442643
# MLSP_Participants/Archaeology/Extra/base_orig/multilex_test